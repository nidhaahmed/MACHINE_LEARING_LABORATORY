# %% [markdown]
# # **PANDAS DATAFRAME**

# %% [markdown]
# Pandas consists of two data structures.
#
#
# 1.   Series
# 2.   Dataframe

# %%
# !pip install pandas
import pandas as pd
import numpy as np

# %%
#Load the path for the dataset into varibale named data_path
data_path = '/content/drive/MyDrive/spd.xlsx'
#load data frame
df = pd.read_excel(data_path)
#Explore dataset
df.head()
# Out:
#    StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0       1001   17       1          0                  2        19.833723
# 1       1002   18       0          0                  1        15.408756
# 2       1003   15       0          2                  3         4.210570
# 3       1004   17       1          0                  3        10.028829
# 4       1005   17       1          0                  2         4.672495
#
#    Absences  Tutoring  ParentalSupport  Extracurricular  Sports  Music  \
# 0         7         1                2                0       0      1
# 1         0         0                1                0       0      0
# 2        26         0                2                0       0      0
# 3        14         0                3                1       0      0
# 4        17         1                3                0       0      0
#
#    Volunteering       GPA  GradeClass
# 0             0  2.929196           2
# ...

# %% [markdown]
# # **Sample Commands**

# %%
df.sample(10)
# Out:
#       StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 326        1327   17       0          2                  4         2.501778
# 514        1515   16       1          3                  2         1.447145
# 2185       3186   17       0          0                  2        16.605004
# 614        1615   16       1          3                  1        10.978650
# 1127       2128   16       0          0                  3         4.297092
# 584        1585   16       1          2                  2        12.276919
# 1764       2765   15       1          1                  1         9.247229
# 338        1339   18       0          2                  0        12.189355
# 1888       2889   17       1          0                  1        10.087614
# 2351       3352   15       0          3                  2         1.889249
#
#       Absences  Tutoring  ParentalSupport  Extracurricular  Sports  Music  \
# ...

# %%
df.columns
# Out:
# Index(['StudentID', 'Age', 'Gender', 'Ethnicity', 'ParentalEducation',
#        'StudyTimeWeekly', 'Absences', 'Tutoring', 'ParentalSupport',
#        'Extracurricular', 'Sports', 'Music', 'Volunteering', 'GPA',
#        'GradeClass'],
#       dtype='object')

# %%
df.tail()
# Out:
#       StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 2387       3388   18       1          0                  3        10.680555
# 2388       3389   17       0          0                  1         7.583217
# 2389       3390   16       1          0                  2         6.805500
# 2390       3391   16       1          1                  0        12.416653
# 2391       3392   16       1          0                  2        17.819907
#
#       Absences  Tutoring  ParentalSupport  Extracurricular  Sports  Music  \
# 2387         2         0                4                1       0      0
# 2388         4         1                4                0       1      0
# 2389        20         0                2                0       0      0
# 2390        17         0                2                0       1      1
# 2391        13         0                2                0       0      0
#
#       Volunteering       GPA  GradeClass
# ...

# %%
print(df[1:100])
# Out:
#     StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 1        1002   18       0          0                  1        15.408756
# 2        1003   15       0          2                  3         4.210570
# 3        1004   17       1          0                  3        10.028829
# 4        1005   17       1          0                  2         4.672495
# 5        1006   18       0          0                  1         8.191219
# ..        ...  ...     ...        ...                ...              ...
# 95       1096   16       1          2                  3        19.278320
# 96       1097   16       1          1                  1        12.831594
# 97       1098   18       0          0                  2         0.468659
# 98       1099   16       0          0                  3         8.603518
# 99       1100   15       0          0                  1        17.500174
#
#     Absences  Tutoring  ParentalSupport  Extracurricular  Sports  Music  \
# ...

# %%
df.iloc[100]
# Out:
# StudentID            1101.000000
# Age                    17.000000
# Gender                  1.000000
# Ethnicity               2.000000
# ParentalEducation       1.000000
# StudyTimeWeekly         6.029124
# Absences               23.000000
# Tutoring                1.000000
# ParentalSupport         1.000000
# Extracurricular         1.000000
# Sports                  1.000000
# Music                   0.000000
# Volunteering            1.000000
# GPA                     1.271230
# GradeClass              4.000000
# Name: 100, dtype: float64

# %%
df['Age'].value_counts()
# Out:
# Age
# 15    630
# 16    593
# 17    587
# 18    582
# Name: count, dtype: int64

# %%
#Mathematical ops
mins = df['StudyTimeWeekly'].min()
maxs = df['StudyTimeWeekly'].max()
means = df['StudyTimeWeekly'].mean()
medians = df['StudyTimeWeekly'].median()
sums = df['StudyTimeWeekly'].sum()
print("Details regarding StudyTimeWeekly")
print("Minimum : ", mins)
print("Maximum : ", maxs)
print("Mean : ", means)
print("Median : ", medians)
print("Sum : ", sums)
# Out:
# Details regarding StudyTimeWeekly
# Minimum :  0.00105653864593602
# Maximum :  19.9780939952615
# Mean :  9.771991919431713
# Median :  9.70536321257439
# Sum :  23374.604671280656

# %% [markdown]
# # **Correlation**

# %% [markdown]
# **Syntax**:
#   DataFrame.corr(self, method=’pearson’, min_periods=1, numeric_only = False)
#
#
# **Parameters**:
#
# **METHOD** :
#
#
# *   **pearson**: standard correlation coefficient
# *   **kendall**: Kendall Tau correlation coefficient
# *   **spearman**: Spearman rank correlation
#
#
#
#
# **min_periods** : Minimum number of observations required per pair of columns to have a valid result. Currently only available for pearson and spearman correlation
#
#
# **numeric_only** : Whether only the numeric values are to be operated upon or not. It is set to False by default.
#
#
# **Returns**:
#
#
# **count** :y : DataFrame

# %%
df.corr(method = 'pearson')
# Out:
#                    StudentID       Age    Gender  Ethnicity  \
# StudentID           1.000000 -0.042255 -0.014625  -0.012990
# Age                -0.042255  1.000000  0.044895  -0.028473
# Gender             -0.014625  0.044895  1.000000   0.016010
# Ethnicity          -0.012990 -0.028473  0.016010   1.000000
# ParentalEducation  -0.002307  0.025099  0.006771   0.033595
# StudyTimeWeekly     0.026976 -0.006800  0.011469   0.007184
# Absences            0.014841 -0.011511  0.021479  -0.025712
# Tutoring           -0.007834 -0.012076 -0.031597  -0.017440
# ParentalSupport     0.003016  0.033197  0.008065   0.020922
# Extracurricular    -0.003611 -0.025061 -0.005964  -0.008927
# Sports             -0.020703 -0.046320 -0.008897  -0.004484
# Music              -0.005468 -0.003492  0.007109  -0.014627
# Volunteering        0.008011  0.013074 -0.000200   0.013468
# GPA                -0.002697  0.000275 -0.013360   0.027760
# GradeClass         -0.098500 -0.006250  0.022998  -0.023326
#
# ...

# %% [markdown]
# # **Standard Deviation**

# %%
df['StudyTimeWeekly'].std()
# Out:
# 5.652774235860243
